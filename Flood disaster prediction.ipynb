# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Hackathon/kerala.csv')

# %%
data.isnull().sum()
# Out:
# SUBDIVISION         0
# YEAR                0
# JAN                 0
# FEB                 0
# MAR                 0
# APR                 0
# MAY                 0
# JUN                 0
# JUL                 0
# AUG                 0
# SEP                 0
# OCT                 0
# NOV                 0
# DEC                 0
#  ANNUAL RAINFALL    0
# FLOODS              0
# dtype: int64

# %%
features = ['YEAR','JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC',' ANNUAL RAINFALL']
target = 'FLOODS'

# %%
from sklearn.model_selection import train_test_split
X= data[features]
y=data[target]

# %% [markdown]
# **Scaling**

# %%
min_max_scaler = preprocessing.MinMaxScaler(feature_range =(-1, 1))


x_after_min_max_scaler = min_max_scaler.fit_transform(X)

print ("\nAfter min max Scaling : \n", x_after_min_max_scaler)
# Out:
# After min max Scaling :
#  [[-1.00000000e+00 -3.12574850e-01  1.31645570e-01 ...  9.11403771e-01
#   -5.22255193e-01 -1.85508693e-02]
#  [-9.82905983e-01 -8.39520958e-01 -9.34177215e-01 ... -2.40945825e-01
#    2.00791296e-01  4.63355794e-02]
#  [-9.65811966e-01 -9.23353293e-01 -5.29113924e-01 ... -2.48727926e-01
#   -4.17408506e-01  2.49563264e-04]
#  ...
#  [ 9.65811966e-01 -9.42514970e-01 -9.03797468e-01 ... -4.37892846e-01
#   -7.67556874e-01 -9.10323600e-01]
#  [ 9.82905983e-01 -9.54491018e-01 -8.27848101e-01 ... -6.34839868e-01
#   -6.24134520e-01 -9.59820314e-01]
#  [ 1.00000000e+00 -3.02994012e-01  3.18987342e-01 ... -4.37892846e-01
#   -3.57072206e-01  1.00000000e+00]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X)
# Out:
#      YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG    SEP  \
# 0    1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5  197.7
# 1    1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8  491.6
# 2    1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2  341.8
# 3    1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8  222.7
# 4    1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6  217.2
# ..    ...   ...   ...   ...    ...    ...     ...     ...     ...    ...
# 113  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9  298.8
# 114  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2  292.9
# 115  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5  173.2
# 116  2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8  209.5
# 117  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9  423.6
#
#        OCT    NOV    DEC   ANNUAL RAINFALL
# 0    266.9  350.8   48.4            3248.6
# ...

# %%
print(y)
# Out:
# 0      YES
# 1      YES
# 2      YES
# 3      YES
# 4       NO
#       ...
# 113    YES
# 114     NO
# 115     NO
# 116     NO
# 117    YES
# Name: FLOODS, Length: 118, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBDIVISION       118 non-null    object
#  1   YEAR              118 non-null    int64
#  2   JAN               118 non-null    float64
#  3   FEB               118 non-null    float64
#  4   MAR               118 non-null    float64
#  5   APR               118 non-null    float64
#  6   MAY               118 non-null    float64
#  7   JUN               118 non-null    float64
#  8   JUL               118 non-null    float64
#  9   AUG               118 non-null    float64
#  10  SEP               118 non-null    float64
#  11  OCT               118 non-null    float64
#  12  NOV               118 non-null    float64
#  13  DEC               118 non-null    float64
#  14   ANNUAL RAINFALL  118 non-null    float64
#  15  FLOODS            118 non-null    object
# ...

# %%
clf=RandomForestClassifier()
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           NO       1.00      0.86      0.92        14
#          YES       0.83      1.00      0.91        10
#
#     accuracy                           0.92        24
#    macro avg       0.92      0.93      0.92        24
# weighted avg       0.93      0.92      0.92        24

# %%
year = input("Enter present Year: ")
print(year)
january = input("Enter Rainfall in January: ")
print(january)
february = input("Enter Rainfall in February: ")
print(february)
march = input("Enter Rainfall in March: ")
print(march)
april = input("Enter Rainfall in April: ")
print(april)
may = input("Enter Rainfall in May: ")
print(may)
june = input("Enter Rainfall in June: ")
print(june)
july = input("Enter Rainfall in July: ")
print(july)
august = input("Enter Rainfall in August: ")
print(august)
september = input("Enter Rainfall in September: ")
print(september)
october = input("Enter Rainfall in October: ")
print(october)
november = input("Enter Rainfall in November: ")
print(november)
december = input("Enter Rainfall in December: ")
print(december)
totalInYear = january + february + march + april + may + june + july + august + september + october + november + december
# Out:
# Enter present Year: 2023
# 2023
# Enter Rainfall in January: 25
# 25
# Enter Rainfall in February: 10
# 10
# Enter Rainfall in March: 45
# 45
# Enter Rainfall in April: 54
# 54
# Enter Rainfall in May: 60
# 60
# Enter Rainfall in June: 80
# 80
# Enter Rainfall in July: 250
# 250
# Enter Rainfall in August: 300
# 300
# Enter Rainfall in September: 400
# 400
# Enter Rainfall in October: 320
# 320
# Enter Rainfall in November: 25
# 25
# Enter Rainfall in December: 10
# 10

# %%
Xnew = [[year, january, february, march, april, may, june, july, august, september, october, november, december, totalInYear]]

ynew = clf.predict(Xnew)
print("X=%s, Predicted=%s" % (Xnew[0], ynew[0]))
# Out:
# X=['2023', '25', '10', '45', '54', '60', '80', '250', '300', '400', '320', '25', '10', '2510455460802503004003202510'], Predicted=YES
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
# Out:
# Enter present Year: 2023
# 2023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fbba22faadb8> in <cell line: 3>()
#       1 year = input("Enter present Year: ")
#       2 print(year)
# ----> 3 january = input("Enter Rainfall in January: ")
#       4 print(january)
#       5 february = input("Enter Rainfall in February: ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...
